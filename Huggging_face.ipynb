# %%
# !pip install -q huggingface_hub

# %%
from huggingface_hub import notebook_login

notebook_login()
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:93: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

base = "/content/drive/MyDrive/saved"

print(os.listdir(base))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_8735/3208371174.py in <cell line: 0>()
#       3 base = "/content/drive/MyDrive/saved"
#       4
# ----> 5 print(os.listdir(base))
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/saved'

# %%
from huggingface_hub import upload_folder

# ----------------------------------------
# CLIP MODEL
# ----------------------------------------

upload_folder(
    repo_id="Sharma-30/fashion-retrieval-assets",
    repo_type="dataset",
    folder_path="/content/drive/MyDrive/saved/clip_finetuned",
    path_in_repo="clip_finetuned"
)

# ----------------------------------------
# EMBEDDINGS
# ----------------------------------------

upload_folder(
    repo_id="Sharma-30/fashion-retrieval-assets",
    repo_type="dataset",
    folder_path="/content/drive/MyDrive/saved/embeddings",
    path_in_repo="embeddings"
)

# ----------------------------------------
# GALLERY
# ----------------------------------------

upload_folder(
    repo_id="Sharma-30/fashion-retrieval-assets",
    repo_type="dataset",
    folder_path="/content/drive/MyDrive/saved/cropped/gallery",
    path_in_repo="gallery"
)
# Out:
# Processing Files (0 / 0)      : |          |  0.00B /  0.00B
# New Data Upload               : |          |  0.00B /  0.00B
#   ...netuned/model.safetensors:   0%|          | 35.1kB /  605MB
# Processing Files (0 / 0)      : |          |  0.00B /  0.00B
# New Data Upload               : |          |  0.00B /  0.00B
#   ...ved/embeddings/emb_B1.npy:   1%|1         |  267kB / 25.8MB
#   ...aved/embeddings/emb_C.npy:   1%|          |  244kB / 25.8MB
#   ...ved/embeddings/emb_C1.npy:   1%|1         |  266kB / 25.8MB
#   ...ed/embeddings/index_A.bin:   0%|          | 1.34kB / 29.3MB
#   ...d/embeddings/index_B1.bin:   1%|          |  266kB / 29.3MB
#   ...ed/embeddings/index_C.bin:   1%|1         |  302kB / 29.3MB
#   ...d/embeddings/index_C1.bin:   0%|          |  137kB / 29.3MB
#   ...ved/embeddings/meta_A.pkl:   1%|1         | 21.2kB / 2.06MB
#   ...ed/embeddings/meta_B1.pkl:   1%|1         | 21.2kB / 2.06MB
#   ...ed/embeddings/meta_B2.pkl:   1%|1         | 21.2kB / 2.06MB
# ...

# %%
# !zip -r gallery.zip /content/drive/MyDrive/saved/cropped/gallery
# Out:
# Streaming output truncated to the last 5000 lines.
#   adding: content/drive/MyDrive/saved/cropped/gallery/WOMEN_Dresses_id_00000674_03_1_front.jpg (deflated 2%)
#   adding: content/drive/MyDrive/saved/cropped/gallery/WOMEN_Dresses_id_00006852_04_1_front.jpg (deflated 1%)
#   adding: content/drive/MyDrive/saved/cropped/gallery/WOMEN_Blouses_Shirts_id_00005311_04_1_front.jpg (deflated 3%)
#   adding: content/drive/MyDrive/saved/cropped/gallery/MEN_Sweatshirts_Hoodies_id_00003853_03_2_side.jpg (deflated 3%)
#   adding: content/drive/MyDrive/saved/cropped/gallery/MEN_Sweatshirts_Hoodies_id_00005910_03_7_additional.jpg (deflated 2%)
#   adding: content/drive/MyDrive/saved/cropped/gallery/WOMEN_Blouses_Shirts_id_00007317_02_2_side.jpg (deflated 2%)
#   adding: content/drive/MyDrive/saved/cropped/gallery/MEN_Sweaters_id_00005021_05_3_back.jpg (deflated 2%)
#   adding: content/drive/MyDrive/saved/cropped/gallery/WOMEN_Tees_Tanks_id_00005392_06_3_back.jpg (deflated 2%)
# ...

# %%
from huggingface_hub import upload_file

upload_file(
    path_or_fileobj="gallery.zip",
    path_in_repo="gallery.zip",
    repo_id="Sharma-30/fashion-retrieval-assets",
    repo_type="dataset"
)
# Out:
# Processing Files (0 / 0)      : |          |  0.00B /  0.00B
# New Data Upload               : |          |  0.00B /  0.00B
#   gallery.zip                 :   1%|          |  526kB / 82.8MB
# CommitInfo(commit_url='https://huggingface.co/datasets/Sharma-30/fashion-retrieval-assets/commit/213651f99b68a740365f71f12c3b10cac6192531', commit_message='Upload gallery.zip with huggingface_hub', commit_description='', oid='213651f99b68a740365f71f12c3b10cac6192531', pr_url=None, repo_url=RepoUrl('https://huggingface.co/datasets/Sharma-30/fashion-retrieval-assets', endpoint='https://huggingface.co', repo_type='dataset', repo_id='Sharma-30/fashion-retrieval-assets'), pr_revision=None, pr_num=None)
